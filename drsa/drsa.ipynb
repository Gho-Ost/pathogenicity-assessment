# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.feature_selection import mutual_info_classif
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.metrics import classification_report
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score
import dalex as dx
from sklearn.model_selection import LeaveOneOut
from sklearn.naive_bayes import GaussianNB
import EDA_module
import DRSA

# %%
EE_015 = pd.read_csv('./data/EE_015/EE_015.csv')
EE_050 = pd.read_csv('./data/EE_050/EE_050.csv')
EE_069 = pd.read_csv('./data/EE_069/EE_069.csv')

# %%
EDA_module.drop_CSQ([EE_015, EE_050, EE_069])

# %%
df = pd.concat([EE_015, EE_050, EE_069], ignore_index=True)
df
# Out:
#        CHROM       POS           ID REF  ALT     QUAL FILTER  \
# 0       chr1     15820    rs2691315   G  [T]      NaN     []
# 1       chr1     17385  rs201535981   G  [A]      NaN     []
# 2       chr1     17697   rs71260069   G  [C]      NaN     []
# 3       chr1    133129  rs367730352   G  [A]      NaN     []
# 4       chr1    183629   rs71267774   G  [A]      NaN     []
# ...      ...       ...          ...  ..  ...      ...    ...
# 444439  chrY  56856571    rs9988391   G  [A]   293.77     []
# 444440  chrY  56856581    rs9320083   G  [A]   750.77     []
# 444441  chrY  56856587    rs7067511   A  [C]  1164.77     []
# 444442  chrY  56856668    rs5013140   A  [G]   467.77     []
# 444443  chrY  56856670    rs5013141   G  [T]   467.77     []
#
#                                FORMAT                    ACMG_class  \
# 0         GT:AB:AD:AF:DP:F1R2:F2R1:SB  ['Uncertain%40Significance']
# 1         GT:AB:AD:AF:DP:F1R2:F2R1:SB  ['Uncertain%40Significance']
# 2         GT:AB:AD:AF:DP:F1R2:F2R1:SB                    ['Benign']
# 3         GT:AB:AD:AF:DP:F1R2:F2R1:SB  ['Uncertain%40Significance']
# 4         GT:AB:AD:AF:DP:F1R2:F2R1:SB                    ['Benign']
# ...                               ...                           ...
# 444439  GT:AB:AD:DP:GQ:PGT:PID:PL:SAC  ['Uncertain%40Significance']
# 444440          GT:AB:AD:DP:GQ:PL:SAC  ['Uncertain%40Significance']
# 444441          GT:AB:AD:DP:GQ:PL:SAC  ['Uncertain%40Significance']
# 444442  GT:AB:AD:DP:GQ:PGT:PID:PL:SAC  ['Uncertain%40Significance']
# 444443  GT:AB:AD:DP:GQ:PGT:PID:PL:SAC  ['Uncertain%40Significance']
#
#        ACMG_coding_impact  ... ClippingRankSum ExcessHet     FS MLEAC  MLEAF  \
# 0        ['non%40coding']  ...             NaN       NaN    NaN   NaN    NaN
# 1        ['non%40coding']  ...             NaN       NaN    NaN   NaN    NaN
# 2        ['non%40coding']  ...             NaN       NaN    NaN   NaN    NaN
# 3        ['non%40coding']  ...             NaN       NaN    NaN   NaN    NaN
# 4        ['non%40coding']  ...             NaN       NaN    NaN   NaN    NaN
# ...                   ...  ...             ...       ...    ...   ...    ...
# 444439   ['non%40coding']  ...             0.0    3.0103  8.315   [1]  [0.5]
# 444440   ['non%40coding']  ...             0.0    3.0103  2.660   [1]  [0.5]
# 444441   ['non%40coding']  ...             0.0    3.0103  0.000   [1]  [0.5]
# 444442   ['non%40coding']  ...             0.0    3.0103  0.000   [1]  [0.5]
# 444443   ['non%40coding']  ...             0.0    3.0103  0.000   [1]  [0.5]
#
#            MQ  MQRankSum     QD ReadPosRankSum    SOR
# 0         NaN        NaN    NaN            NaN    NaN
# 1         NaN        NaN    NaN            NaN    NaN
# 2         NaN        NaN    NaN            NaN    NaN
# 3         NaN        NaN    NaN            NaN    NaN
# 4         NaN        NaN    NaN            NaN    NaN
# ...       ...        ...    ...            ...    ...
# 444439  41.25     -0.431   5.76         -1.020  0.419
# 444440  41.23     -2.005  16.68         -0.205  0.361
# 444441  40.19     -3.699  31.48         -1.691  0.530
# 444442  44.02     -1.952  33.41          0.183  2.985
# 444443  44.02     -1.952  33.41          0.549  2.985
#
# [444444 rows x 76 columns]

# %%
df=EDA_module.drop_ACMG_AMP(df)

# %%
df=EDA_module.drop_Nans_threshold(df, 400000)

# %%
map=EDA_module.get_ACMG_mapping(df)
map
# Out:
# {"['Uncertain%40Significance']": 4,
#  "['Benign']": 0,
#  "['Likely%40Benign']": 1,
#  "['Likely%40Pathogenic']": 2,
#  "['Pathogenic']": 3}

# %%
imputer = SimpleImputer(strategy='median')
X = df.drop(columns=['ACMG_class'])
for x in X:
    X[x+"-"] = X[x]

X = pd.DataFrame(imputer.fit_transform(X), columns=X.columns)
y = df['ACMG_class']

# %%
trainFraction = 0.7
valFraction = 0.15
testFraction = 0.15
size = df.shape[0]
idx = np.arange(size)
np.random.shuffle(idx)
trainX, trainY = X.loc[idx[:int(trainFraction*size)]].reset_index(drop=True), y[idx[:int(trainFraction*size)]]
valX = X.loc[idx[int(trainFraction*size):int((trainFraction+valFraction)*size)]].reset_index(drop=True)
valY = y[idx[int(trainFraction*size):int((trainFraction+valFraction)*size)]]
testX = X.loc[idx[int((trainFraction+valFraction)*size):]].reset_index(drop=True)
testY = y[idx[int((trainFraction+valFraction)*size):]]

# %%
drsa_params=([1]*53)+([-1]*53)
drsa = DRSA.DRSA(drsa_params, credibility=0.9)
drsa.fit(trainX, trainY.reset_index(drop=True))
pred2 = drsa.predict(valX)
# Out:
# class <= 0
# class <= 1
# class <= 2
# class <= 3
# class >= 1
# class >= 2
# class >= 3
# class >= 4
# ('gnomadGenomes_AF-', <built-in function ge>, 3015.0)
# 268758 298339
# Class <=0 if gnomadGenomes_AF- >= 3015.0 268758 298339
# ('FILTER-', <built-in function ge>, 66.0)
# 261878 288706
# Class <=0 if FILTER- >= 66.0 261878 288706
# ('gnomadGenomes_AF_ethnic-', <built-in function ge>, 3600.0)
# 268435 297659
# Class <=0 if gnomadGenomes_AF_ethnic- >= 3600.0 268435 297659
# ('FILTER-', <built-in function ge>, 64.0)
# 263186 290614
# Class <=0 if FILTER- >= 64.0 263186 290614
# ('gnomadGenomesAN-', <built-in function ge>, 8033.0)
# 262061 288140
# Class <=0 if gnomadGenomesAN- >= 8033.0 262061 288140
# 5
# 4
# ('ECNT', <built-in function ge>, 27.0)
# 830 852
# Class >=1 if ECNT >= 27.0 830 852
# ('gnomadGenomes_AF_ethnic-', <built-in function le>, 7060.0)
# 14915 16269
# Class >=1 if gnomadGenomes_AF_ethnic- <= 7060.0 14915 16269
# ('gnomadGenomesEthnic_AC_Hom-', <built-in function le>, 0.0)
# 27866 31346
# ('GERMQ', <built-in function ge>, 31.0)
# 26127 28952
# Class >=1 if gnomadGenomesEthnic_AC_Hom- <= 0.0 and GERMQ >= 31.0 26127 28952
# ('gnomadGenomes_AF-', <built-in function le>, 16340.0)
# 19038 23000
# ('GERMQ', <built-in function ge>, 34.0)
# 12848 14247
# Class >=1 if gnomadGenomes_AF- <= 16340.0 and GERMQ >= 34.0 12848 14247
# ('ECNT', <built-in function ge>, 5.0)
# 12211 17858
# ('MMQ-', <built-in function le>, 17.0)
# 3870 4264
# Class >=1 if ECNT >= 5.0 and MMQ- <= 17.0 3870 4264
# ('ECNT', <built-in function ge>, 5.0)
# 12211 17858
# ('CHROM', <built-in function ge>, 47.0)
# 2367 2637
# ('cosmicFathMMScore', <built-in function ge>, 0.00019)
# 2367 2629
# Class >=1 if ECNT >= 5.0 and CHROM >= 47.0 and cosmicFathMMScore >= 0.00019 2367 2629
# ('ECNT', <built-in function ge>, 5.0)
# 12211 17858
# ('gnomadGenomesAN-', <built-in function le>, 7254.0)
# 5618 6008
# Class >=1 if ECNT >= 5.0 and gnomadGenomesAN- <= 7254.0 5618 6008
# ('ECNT', <built-in function ge>, 5.0)
# 12211 17858
# ('gnomadGenomesAN-', <built-in function le>, 13162.0)
# 6894 7812
# ('gnomadGenomes_AF-', <built-in function le>, 169888.0)
# 6701 7440
# Class >=1 if ECNT >= 5.0 and gnomadGenomesAN- <= 13162.0 and gnomadGenomes_AF- <= 169888.0 6701 7440
# ('MQ-', <built-in function le>, 26.66)
# 626 760
# ('gnomadExomesEthnic_AC_Hom-', <built-in function le>, -1.0)
# 566 624
# Class >=1 if MQ- <= 26.66 and gnomadExomesEthnic_AC_Hom- <= -1.0 566 624
# ('MQ-', <built-in function le>, 30.89)
# 1473 1917
# ('MQ', <built-in function ge>, 30.89)
# 3 3
# Class >=1 if MQ- <= 30.89 and MQ >= 30.89 3 3
# ('gnomadGenomes_AF-', <built-in function le>, 12806.0)
# 17898 20310
# ('CGDinheritance-', <built-in function le>, -1.0)
# 16451 17858
# Class >=1 if gnomadGenomes_AF- <= 12806.0 and CGDinheritance- <= -1.0 16451 17858
# ('MQ-', <built-in function le>, 30.52)
# 1408 1820
# ('function-', <built-in function le>, 130.0)
# 494 546
# Class >=1 if MQ- <= 30.52 and function- <= 130.0 494 546
# ('gnomadGenomesAN', <built-in function ge>, 23618.0)
# 5550 7628
# ('gnomadGenomesAN-', <built-in function le>, 23618.0)
# 2 2
# Class >=1 if gnomadGenomesAN >= 23618.0 and gnomadGenomesAN- <= 23618.0 2 2
# ('gnomadGenomesAN', <built-in function ge>, 22149.0)
# 6741 9290
# ('gnomadGenomesAN-', <built-in function le>, 22149.0)
# 1 1
# Class >=1 if gnomadGenomesAN >= 22149.0 and gnomadGenomesAN- <= 22149.0 1 1
# ('gnomadGenomesAN-', <built-in function le>, 3687.0)
# 12652 16320
# ('gnomadGenomesAC-', <built-in function le>, 8547.0)
# 10722 11075
# Class >=1 if gnomadGenomesAN- <= 3687.0 and gnomadGenomesAC- <= 8547.0 10722 11075
# ('gnomadGenomesAN-', <built-in function le>, 9107.0)
# 16961 24637
# ('POS-', <built-in function le>, 15613062.0)
# 7568 8709
# ('gnomadGenomes_AF-', <built-in function le>, 154085.0)
# 7354 8160
# Class >=1 if gnomadGenomesAN- <= 9107.0 and POS- <= 15613062.0 and gnomadGenomes_AF- <= 154085.0 7354 8160
# ('gnomadGenomesAN', <built-in function ge>, 25181.0)
# 4191 5869
# ('gnomadGenomesAN-', <built-in function le>, 25181.0)
# 1 1
# Class >=1 if gnomadGenomesAN >= 25181.0 and gnomadGenomesAN- <= 25181.0 1 1
# ('gnomadGenomesAN-', <built-in function le>, 5155.0)
# 13449 18858
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17300/3401206833.py in <module>
#       1 drsa_params=([1]*53)+([-1]*53)
#       2 drsa = DRSA.DRSA(drsa_params, credibility=0.9)
# ----> 3 drsa.fit(trainX, trainY.reset_index(drop=True))
#       4 pred2 = drsa.predict(valX)
#
# c:\Users\creep\Desktop\studia\sem5\problem classes\pathogenicity-assessment\DRSA.py in fit(self, df, target)
#     193         for i in range(len(self.lowerApproximation[0])):
#     194             self.rules += LEM2(self.lowerApproximation[0][i], self, -1, i, credibility=self.credibility)
# --> 195             self.rules += LEM2(self.lowerApproximation[1][i], self, 1, i+1, credibility=self.credibility)
#     196
#     197         tmp = target.groupby(target).groups
#
# c:\Users\creep\Desktop\studia\sem5\problem classes\pathogenicity-assessment\DRSA.py in LEM2(toCoverIdx, roughSet, direction, target, credibility)
#      68                 b = tmpRule.apply(roughSet.df).sum()
#      69                 a = tmpRule.apply(tmpLeft).sum()
# ---> 70                 d = tmpRule.apply(toCover).sum()
#      71                 c = min(d/b, credibility)
#      72 #                 b = a
#
# c:\Users\creep\Desktop\studia\sem5\problem classes\pathogenicity-assessment\DRSA.py in apply(self, df)
#      23         result = pd.Series(np.ones_like(df.iloc[:,0]).astype(bool), index=df.index)
#      24         for i in range(len(self.columns)):
# ---> 25             result &= self.operators[i](df[self.columns[i]], self.values[i])
#      26         return result
#      27
#
# c:\Users\creep\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# c:\Users\creep\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py in __ge__(self, other)
#      50     @unpack_zerodim_and_defer("__ge__")
#      51     def __ge__(self, other):
# ---> 52         return self._cmp_method(other, operator.ge)
#      53
#      54     # -------------------------------------------------------------
#
# c:\Users\creep\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5500
#    5501         with np.errstate(all="ignore"):
# -> 5502             res_values = ops.comparison_op(lvalues, rvalues, op)
#    5503
#    5504         return self._construct_result(res_values, name=res_name)
#
# c:\Users\creep\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     285
#     286     else:
# --> 287         res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#     288
#     289     return res_values
#
# c:\Users\creep\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     164
#     165     try:
# --> 166         result = func(left, right)
#     167     except TypeError:
#     168         if is_object_dtype(left) or is_object_dtype(right) and not is_cmp:
#
# c:\Users\creep\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     237         if use_numexpr:
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#     241
#
# c:\Users\creep\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      67     if _TEST_MODE:
#      68         _store_test_result(False)
# ---> 69     return op(a, b)
#      70
#      71
#
# KeyboardInterrupt:
